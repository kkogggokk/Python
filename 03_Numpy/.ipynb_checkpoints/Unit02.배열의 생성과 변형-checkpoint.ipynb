# %% [markdown]
# # 2.1 넘파이 자료형

# %% [markdown]
# # 2.2 Inf와 NaN

# %% [markdown]
# # 2.3 배열생성

# %% [markdown]
# ### 2.3.1 zeros

# %% [markdown]
# ### 2.3.2 onew

# %% [markdown]
# ### 2.3.3 zeros_like

# %% [markdown]
# ### 2.3.4 ones_like

# %% [markdown]
# ### 2.3.5 empty

# %% [markdown]
# ### 2.3.6 arange

# %% [markdown]
# ### 2.3.7 linspace

# %% [markdown]
# ### 2.3.8 logspace

# %% [markdown]
# ### 2.3.9 full

# %% [markdown]
# ### 2.3.10 eye

# %% [markdown]
# ## 2.4 전치연산

# %% [markdown]
# ## 2.5 배열의 형태변경

# %% [markdown]
# ### 2.5.1 reshape

# %% [markdown]
# ### 2.5.2 newaxis

# %% [markdown]
# ### 2.5.3 expand_dims

# %% [markdown]
# ### 2.5.4 squeeze

# %% [markdown]
# ### 2.5.5 flatten, ravel

# %% [markdown]
# ## 2.6 배열연결

# %% [markdown]
# ### 2.6.1 concatenate

# %% [markdown]
# ### 2.6.2 hstack

# %% [markdown]
# ### 2.6.3 vstack

# %% [markdown]
# ### 2.6.4 dstack

# %% [markdown]
# ### 2.6.5 stack

# %% [markdown]
# ### 2.6.6 r_

# %% [markdown]
# ### 2.6.7 c_

# %% [markdown]
# ### 2.6.8 tile

# %% [markdown]
# ## 2.9 배열분할하기

# %% [markdown]
# ### 2.9.1 split

# %% [markdown]
# ### 2.9.2 hsplit

# %% [markdown]
# ### 2.9.3 vsplit

# %% [markdown]
# ## 2.10 추가 및 삭제

# %% [markdown]
# ### 2.10.1 append

# %% [markdown]
# ### 2.10.2 insert

# %% [markdown]
# ### 2.10.3 delete
