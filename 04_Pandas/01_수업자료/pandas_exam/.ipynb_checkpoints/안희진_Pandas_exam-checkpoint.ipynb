# %% [markdown]
# # Seoul_report.csv 읽기
# + 서울시 주민등록인구 (구별) 통계 - [서울열린데이터광장 ](http://data.seoul.go.kr/dataList/datasetView.do?serviceKind=2&infId=419&stcSrl=419&srvType=S)
# - [통계청kosis](https://kosis.kr/index/index.do)
# - [UCI](https://archive.ics.uci.edu/ml/index.php)

# %% [markdown]
# ## 1. CSV 파일 읽기
# - Seoul_report.csv 파일의 내용을 DataFrame으로 읽고 변수에 대입

# %%
import numpy as np
import pandas as pd

# %%
df_raw = pd.read_csv('Seoul_report.csv') # index = False로 주고싶은데 왜 에러? 어떨때 false? 
df_raw
df_raw.shape
df_raw.columns
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   자치구       26 non-null     object
#  1   세대        26 non-null     int64
#  2   총합계       26 non-null     int64
#  3   남자        26 non-null     int64
#  4   여자        26 non-null     int64
#  5   한국인합계     26 non-null     int64
#  6   한국인남자     26 non-null     int64
#  7   한국인여자     26 non-null     int64
#  8   외국인합계     26 non-null     int64
#  9   남자외국인     26 non-null     int64
#  10  여자외국인     26 non-null     int64
#  11  세대당인구     26 non-null     float64
#  12  65세이상고령자  26 non-null     int64
# dtypes: float64(1), int64(11), object(1)
# memory usage: 2.8+ KB

# %% [markdown]
# # 2. 열명 변경
# - 읽은 DataFrame에 어떤 컬럼이 있는지 확인하고 열명을 아래와 같이 바꾼다. (이외 열이름은 그대로 유지)
#     - '총합계' : '총인구'
#     - '한국인합계': '한국인'
#     - '외국인합계' : '외국인'
#     - '65세이상고령자' : '고령자'

# %%
# seoul_df.info()

# ch_columns = ['자치구','세대','총인구','남자','여자','한국인','한국인남자','한국인여자','외국인','남자외국인','여자외국인','세대당인구','고령자']
# df_raw.columns = [ch_columns] 
# seoul_df 

dic = {'총합계':'총인구', '한국인합계' : '한국인', '외국인합계' : '외국인', '65세이상고령자' : '고령자'}
df_raw.rename(dic, axis = 1, inplace = True) # 원본 바꾸고 싶으면 inplace = true

# %%
df_raw.head() # 결과 확인할 때 이왕이면 따로 지정해서 출력하는게 좋음, 한번 더 실행하면 결과가 라질수도 있기 때문에
# Out:
#    자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0   합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 1  종로구    73879    164348    79962    84386   154549    75749    78800
# 2   중구    60903    135139    66582    68557   126082    62376    63706
# 3  용산구   108497    245411   119985   125426   229909   111262   118647
# 4  성동구   134543    314551   154672   159879   306532   150937   155595
#
#       외국인   남자외국인   여자외국인  세대당인구      고령자
# 0  273178  130974  142204   2.32  1382420
# 1    9799    4213    5586   2.09    26429
# 2    9057    4206    4851   2.07    21655
# 3   15502    8723    6779   2.12    37238
# 4    8019    3735    4284   2.28    41752

# %% [markdown]
# 컬럼 변경 방법 2가지
# 1. df.columns = []
#     - 이 방법은 전체 다 입력해줘야 함.
# 1. df.rename = ({'변경전컬럼명' : '변경후컬럼명'})

# %% [markdown]
# # 3. 사용할 열들만 추출
# - 자치구, 총인구, 한국인, 외국인, 고령자 열만 가지는 dataframe 생성
#     - shape이 (5, n) 이 되도록

# %%
df = df_raw[['자치구', '총인구', '한국인', '외국인', '고령자']]
df.shape
# Out:
# (26, 5)

# %% [markdown]
# <설명>
# - 인덱싱은 원본을 변경하는 것이 아니라 복사본이다.

# %% [markdown]
# # 4. DataFrame 개괄 정보 조회
# 1. 몇행/몇열인지 조회
# 1. 결측치가 있는지 조회
# 1. DataFrame에 대한 정보(index, columns) 확인
# 1. 상위 5개 행만 조회
# 1. 하위 5개 행만 조회
# 1. 컬럼별 통계량 요약 조회

# %%
df.shape
# Out:
# (26, 13)

# %%
# 이거 다시 확인 
df.isnull()
# Out:
#       자치구    총인구    한국인    외국인    고령자
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# 5   False  False  False  False  False
# 6   False  False  False  False  False
# 7   False  False  False  False  False
# 8   False  False  False  False  False
# 9   False  False  False  False  False
# 10  False  False  False  False  False
# 11  False  False  False  False  False
# 12  False  False  False  False  False
# 13  False  False  False  False  False
# 14  False  False  False  False  False
# 15  False  False  False  False  False
# 16  False  False  False  False  False
# 17  False  False  False  False  False
# 18  False  False  False  False  False
# 19  False  False  False  False  False
# 20  False  False  False  False  False
# 21  False  False  False  False  False
# 22  False  False  False  False  False
# 23  False  False  False  False  False
# ...

# %%
# DataFrame에 대한 정보(index, columns) 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     26 non-null     object
#  1   총인구     26 non-null     int64
#  2   한국인     26 non-null     int64
#  3   외국인     26 non-null     int64
#  4   고령자     26 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.1+ KB

# %%
df.head(5)

# %%
df.tail(5)

# %%
# 컬럼별 통계량 요약 조회
df.describe()
# Out:
#                 총인구           한국인            외국인           고령자
# count  2.600000e+01  2.600000e+01      26.000000  2.600000e+01
# mean   7.778515e+05  7.568378e+05   21013.692308  1.063400e+05
# std    1.907984e+06  1.856777e+06   52081.287523  2.606869e+05
# min    1.351390e+05  1.260820e+05    2180.000000  2.165500e+04
# 25%    3.318935e+05  3.286118e+05    4434.250000  4.976425e+04
# 50%    4.091335e+05  4.006105e+05    9428.000000  5.663350e+04
# 75%    4.859615e+05  4.817318e+05   15257.000000  6.663675e+04
# max    1.011207e+07  9.838892e+06  273178.000000  1.382420e+06

# %% [markdown]
# # 5. 열이름으로 조회
# 1. 총인구 열의 모든 값들을 조회
# 1. 한국인, 외국인 열의 모든 값들을 조회

# %%
df_raw.loc[:,['총인구']]
df['총인구']
# Out:
# 0     10112070
# 1       164348
# 2       135139
# 3       245411
# 4       314551
# 5       371671
# 6       364962
# 7       411552
# 8       453902
# 9       327511
# 10      345041
# 11      555803
# 12      490253
# 13      324871
# 14      385624
# 15      473087
# 16      608361
# 17      440396
# 18      253344
# 19      403988
# 20      406715
# 21      522292
# 22      445164
# 23      557865
# 24      671994
# 25      438225
# Name: 총인구, dtype: int64

# %%
# seoul_df.loc[:,['한국인','외국인']]
df[['한국인','외국인']]
# Out:
#         한국인     외국인
# 0   9838892  273178
# 1    154549    9799
# 2    126082    9057
# 3    229909   15502
# 4    306532    8019
# 5    357149   14522
# 6    349308   15654
# 7    406868    4684
# 8    442226   11676
# 9    323862    3649
# 10   342861    2180
# 11   551902    3901
# 12   485902    4351
# 13   312311   12560
# 14   374742   10882
# 15   469221    3866
# 16   601696    6665
# 17   408369   32027
# 18   234238   19106
# 19   369128   34860
# 20   394353   12362
# 21   504445   17847
# 22   440954    4210
# 23   552976    4889
# 24   665282    6712
# 25   434027    4198

# %% [markdown]
# # 6. 행기준 조회
# 1. 5번째 행의 데이터를 조회.
# 1. 1, 5, 7, 10 번째 행의 데이터를 조회
# 1. 15 ~ 20 번째 행의 데이터를 조회
# 1. 10~15 행에서 자치구, 총인구, 한국인 열의 값을 조회
# 1. 6, 7, 8 번째 행의 한국인, 외국인 열의 값을 조회

# %% [markdown]
# - iloc
# - loc

# %%
# 5번째 행의 데이터를 조회.
df.iloc[4]
# Out:
# 자치구       성동구
# 총인구    314551
# 한국인    306532
# 외국인      8019
# 고령자     41752
# Name: 4, dtype: object

# %%
# 1, 5, 7, 10 번째 행의 데이터를 조회
df.iloc[[0, 4, 6, 9]]
# Out:
#     자치구       총인구      한국인     외국인      고령자
# 0    합계  10112070  9838892  273178  1382420
# 4   성동구    314551   306532    8019    41752
# 6  동대문구    364962   349308   15654    56284
# 9   강북구    327511   323862    3649    57002

# %%
#15 ~ 20 번째 행의 데이터를 조회
df.iloc[14:21]
# Out:
#      자치구     총인구     한국인    외국인    고령자
# 14   마포구  385624  374742  10882  50122
# 15   양천구  473087  469221   3866  56070
# 16   강서구  608361  601696   6665  77381
# 17   구로구  440396  408369  32027  59838
# 18   금천구  253344  234238  19106  34640
# 19  영등포구  403988  369128  34860  54704
# 20   동작구  406715  394353  12362  57711

# %%
# 10~15 행에서 자치구, 총인구, 한국인 열의 값을 조회
df.loc[10:15,['자치구','총인구','한국인']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-fdf6e360992f> in <module>
#       1 # 10~15 행에서 자치구, 총인구, 한국인 열의 값을 조회
# ----> 2 df.iloc[10:15,['자치구','총인구','한국인']]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# ...

# %%
# 6, 7, 8 번째 행의 한국인, 외국인 열의 값을 조회
df.loc[6:8,['한국인','외국인']]
# Out:
#       한국인    외국인
# 6  349308  15654
# 7  406868   4684
# 8  442226  11676

# %% [markdown]
# # 7. index 이름 지정
# 1. '자치구' 열을 index로 설정
# 1. 데이터 프레임의 index이름 조회
# 1. 강남구 행 조회
# 1. 종로구, 성동구, 서대문구 행 조회
# 1. 노원구 ~ 금천구 조회
# 1. 종로구의 한국인,외국인 열의 값 조회
# 1. 도봉구, 노원구, 송파구의 총인구와 고령자 열의 값 조회

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     26 non-null     object
#  1   총인구     26 non-null     int64
#  2   한국인     26 non-null     int64
#  3   외국인     26 non-null     int64
#  4   고령자     26 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.1+ KB

# %%
# 1. '자치구' 열을 index로 설정
# seoul_df_1.set_index('자치구') # 왜 셋인덱스가 잘 안먹히지... only integer scalar arrays can be converted to a scalar index
new_df = seoul_df_1.set_index('자치구',) #why? 
new_df
# Out:
#            세대       총인구       남자       여자      한국인    한국인남자    한국인여자     외국인  \
# 자치구
# 합계    4237610  10112070  4948481  5163589  9838892  4817507  5021385  273178
# 종로구     73879    164348    79962    84386   154549    75749    78800    9799
# 중구      60903    135139    66582    68557   126082    62376    63706    9057
# 용산구    108497    245411   119985   125426   229909   111262   118647   15502
# 성동구    134543    314551   154672   159879   306532   150937   155595    8019
# 광진구    161407    371671   180206   191465   357149   173946   183203   14522
# 동대문구   160489    364962   180381   184581   349308   174476   174832   15654
# 중랑구    179600    411552   204411   207141   406868   202526   204342    4684
# 성북구    187234    453902   220024   233878   442226   215421   226805   11676
# 강북구    143139    327511   159853   167658   323862   158440   165422    3649
# 도봉구    137479    345041   168833   176208   342861   168009   174852    2180
# ...

# %%
# 2. 데이터 프레임의 index이름 조회
new_df.index
# Out:
# Index(['합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구',
#        '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype='object', name='자치구')

# %%
# 3. 강남구 행 조회
new_df.loc['강남구']
# Out:
# 세대       231219.00
# 총인구      557865.00
# 남자       267314.00
# 여자       290551.00
# 한국인      552976.00
# 한국인남자    264834.00
# 한국인여자    288142.00
# 외국인        4889.00
# 남자외국인      2480.00
# 여자외국인      2409.00
# 세대당인구         2.39
# 고령자       65859.00
# Name: 강남구, dtype: float64

# %%
# 4. 종로구, 성동구, 서대문구 행 조회
new_df.loc[['종로구','성동구','서대문구']]
# Out:
#           세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  남자외국인  \
# 자치구
# 종로구    73879  164348   79962   84386  154549   75749   78800   9799   4213
# 성동구   134543  314551  154672  159879  306532  150937  155595   8019   3735
# 서대문구  137758  324871  154960  169911  312311  150793  161518  12560   4167
#
#       여자외국인  세대당인구    고령자
# 자치구
# 종로구    5586   2.09  26429
# 성동구    4284   2.28  41752
# 서대문구   8393   2.27  49645

# %%
# 5. 노원구 ~ 금천구 조회
new_df.loc['노원구':'금천구']
# Out:
#           세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  남자외국인  \
# 자치구
# 노원구   217999  555803  269762  286041  551902  268144  283758   3901   1618
# 은평구   203431  490253  237542  252711  485902  235674  250228   4351   1868
# 서대문구  137758  324871  154960  169911  312311  150793  161518  12560   4167
# 마포구   170219  385624  182905  202719  374742  178661  196081  10882   4244
# 양천구   176559  473087  233189  239898  469221  231409  237812   3866   1780
# 강서구   256042  608361  296098  312263  601696  292871  308825   6665   3227
# 구로구   171751  440396  220903  219493  408369  202731  205638  32027  18172
# 금천구   106333  253344  129791  123553  234238  119023  115215  19106  10768
#
#       여자외국인  세대당인구    고령자
# 자치구
# 노원구    2283   2.53  75081
# 은평구    2483   2.39  75535
# 서대문구   8393   2.27  49645
# 마포구    6638   2.20  50122
# 양천구    2086   2.66  56070
# 강서구    3438   2.35  77381
# 구로구   13855   2.38  59838
# 금천구    8338   2.20  34640

# %%
# 6. 종로구의 한국인,외국인 열의 값 조회
new_df.loc['종로구',['한국인','외국인']]
# Out:
# 한국인    154549.0
# 외국인      9799.0
# Name: 종로구, dtype: float64

# %%
# 7. 도봉구, 노원구, 송파구의 총인구와 고령자 열의 값 조회
new_df.loc[['도봉구','노원구','송파구'],['총인구','고령자']]
# Out:
#         총인구    고령자
# 자치구
# 도봉구  345041  54293
# 노원구  555803  75081
# 송파구  671994  77978

# %% [markdown]
# # 8. Boolean 인덱싱 - 조건으로 조회
# 1. 총인구가 500,000 이상인 행 조회
# 1. 외국인이 15,000 이상인 행의 한국인, 외국인 열 조회
# 1. 외국인이 고령자보다 많은 행을 조회 (없으므로 아무 행도 안나오는게 정상임)
# 1. 고령자수가 60,000 ~ 70,000 인 행 조회
# 1. 외국인이 15,000 이상이고 고령자가 50,000 이상인 행을 조회

# %%
# 1. 총인구가 500,000 이상인 행 조회
# new_df[new_df['총인구'] >= 500000]
seoul_df_1[seoul_df_1['총인구'] >= 500000]
# Out:
#     자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0    합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 11  노원구   217999    555803   269762   286041   551902   268144   283758
# 16  강서구   256042    608361   296098   312263   601696   292871   308825
# 21  관악구   258536    522292   262428   259864   504445   253911   250534
# 23  강남구   231219    557865   267314   290551   552976   264834   288142
# 24  송파구   266550    671994   326511   345483   665282   323228   342054
#
#        외국인   남자외국인   여자외국인  세대당인구      고령자
# 0   273178  130974  142204   2.32  1382420
# 11    3901    1618    2283   2.53    75081
# 16    6665    3227    3438   2.35    77381
# 21   17847    8517    9330   1.95    70807
# 23    4889    2480    2409   2.39    65859
# 24    6712    3283    3429   2.50    77978

# %%
# 2. 외국인이 15,000 이상인 행의 한국인, 외국인 열 조회
# new_df.loc[new_df['외국인'] >= 15000,['한국인','외국인']]
seoul_df_1.loc[seoul_df_1['외국인'] >= 15000,['한국인','외국인']]
# Out:
#         한국인     외국인
# 0   9838892  273178
# 3    229909   15502
# 6    349308   15654
# 17   408369   32027
# 18   234238   19106
# 19   369128   34860
# 21   504445   17847

# %%
# 3. 외국인이 고령자보다 많은 행을 조회 (없으므로 아무 행도 안나오는게 정상임)
seoul_df_1[seoul_df_1['외국인'] > seoul_df_1['고령자']]
# Out:
# Empty DataFrame
# Columns: [자치구, 세대, 총인구, 남자, 여자, 한국인, 한국인남자, 한국인여자, 외국인, 남자외국인, 여자외국인, 세대당인구, 고령자]
# Index: []

# %%
# 4. 고령자수가 60,000 ~ 70,000 인 행 조회
# seoul_df_1[(seoul_df_1['고령자']>= 60000) & (seoul_df_1['고령자']<= 70000)]

# 시리즈.between(a, b) : between a and b 
df.loc[df['고령자'].between(60000,70000)]
# Out:
#     자치구     총인구     한국인    외국인    고령자
# 8   성북구  453902  442226  11676  66896
# 23  강남구  557865  552976   4889  65859

# %%
# 5. 외국인이 15,000 이상이고 고령자가 50,000 이상인 행을 조회
seoul_df_1[(seoul_df_1['외국인'] >= 15000) & (seoul_df_1['고령자'] >= 50000)]
# Out:
#      자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0     합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 6   동대문구   160489    364962   180381   184581   349308   174476   174832
# 17   구로구   171751    440396   220903   219493   408369   202731   205638
# 19  영등포구   168784    403988   203472   200516   369128   184127   185001
# 21   관악구   258536    522292   262428   259864   504445   253911   250534
#
#        외국인   남자외국인   여자외국인  세대당인구      고령자
# 0   273178  130974  142204   2.32  1382420
# 6    15654    5905    9749   2.18    56284
# 17   32027   18172   13855   2.38    59838
# 19   34860   19345   15515   2.19    54704
# 21   17847    8517    9330   1.95    70807

# %% [markdown]
# # 9. 정렬
# 1. 자치구컬럼 기준 오름차순 순으로 정렬
# 1. 자치구컬럼 기준 내림차순 순으로 정렬
# 1. 외국인이 많이 있는 순으로 정렬
# 1. 한국인이 많이 있는 순서로 정렬하고 혹시 같으면 고령자가 적은 순으로 2차 정렬
# 1. 합계를 지우고 총인구 내림차순으로 정렬

# %%
# 1. 자치구컬럼 기준 오름차순 순으로 정렬
seoul_df_1.sort_values('자치구')
# Out:
#      자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 23   강남구   231219    557865   267314   290551   552976   264834   288142
# 25   강동구   177490    438225   217570   220655   434027   215588   218439
# 9    강북구   143139    327511   159853   167658   323862   158440   165422
# 16   강서구   256042    608361   296098   312263   601696   292871   308825
# 21   관악구   258536    522292   262428   259864   504445   253911   250534
# 5    광진구   161407    371671   180206   191465   357149   173946   183203
# 17   구로구   171751    440396   220903   219493   408369   202731   205638
# 18   금천구   106333    253344   129791   123553   234238   119023   115215
# 11   노원구   217999    555803   269762   286041   551902   268144   283758
# 10   도봉구   137479    345041   168833   176208   342861   168009   174852
# 6   동대문구   160489    364962   180381   184581   349308   174476   174832
# 20   동작구   173544    406715   197848   208867   394353   192215   202138
# ...

# %%
# 2. 자치구컬럼 기준 내림차순 순으로 정렬
seoul_df_1.sort_values('자치구', ascending=False)
# Out:
#      자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0     합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 7    중랑구   179600    411552   204411   207141   406868   202526   204342
# 2     중구    60903    135139    66582    68557   126082    62376    63706
# 1    종로구    73879    164348    79962    84386   154549    75749    78800
# 12   은평구   203431    490253   237542   252711   485902   235674   250228
# 3    용산구   108497    245411   119985   125426   229909   111262   118647
# 19  영등포구   168784    403988   203472   200516   369128   184127   185001
# 15   양천구   176559    473087   233189   239898   469221   231409   237812
# 24   송파구   266550    671994   326511   345483   665282   323228   342054
# 8    성북구   187234    453902   220024   233878   442226   215421   226805
# 4    성동구   134543    314551   154672   159879   306532   150937   155595
# 22   서초구   174225    445164   213279   231885   440954   211156   229798
# ...

# %%
# 3. 외국인이 많이 있는 순으로 정렬
seoul_df_1.sort_values('외국인', ascending=False)
# Out:
#      자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0     합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 19  영등포구   168784    403988   203472   200516   369128   184127   185001
# 17   구로구   171751    440396   220903   219493   408369   202731   205638
# 18   금천구   106333    253344   129791   123553   234238   119023   115215
# 21   관악구   258536    522292   262428   259864   504445   253911   250534
# 6   동대문구   160489    364962   180381   184581   349308   174476   174832
# 3    용산구   108497    245411   119985   125426   229909   111262   118647
# 5    광진구   161407    371671   180206   191465   357149   173946   183203
# 13  서대문구   137758    324871   154960   169911   312311   150793   161518
# 20   동작구   173544    406715   197848   208867   394353   192215   202138
# 8    성북구   187234    453902   220024   233878   442226   215421   226805
# 14   마포구   170219    385624   182905   202719   374742   178661   196081
# ...

# %%
# 4. 한국인이 많이 있는 순서로 정렬하고 혹시 같으면 고령자가 적은 순으로 2차 정렬
seoul_df_1.sort_values(['한국인','고령자'],ascending = False)
# Out:
#      자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0     합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 24   송파구   266550    671994   326511   345483   665282   323228   342054
# 16   강서구   256042    608361   296098   312263   601696   292871   308825
# 23   강남구   231219    557865   267314   290551   552976   264834   288142
# 11   노원구   217999    555803   269762   286041   551902   268144   283758
# 21   관악구   258536    522292   262428   259864   504445   253911   250534
# 12   은평구   203431    490253   237542   252711   485902   235674   250228
# 15   양천구   176559    473087   233189   239898   469221   231409   237812
# 8    성북구   187234    453902   220024   233878   442226   215421   226805
# 22   서초구   174225    445164   213279   231885   440954   211156   229798
# 25   강동구   177490    438225   217570   220655   434027   215588   218439
# 17   구로구   171751    440396   220903   219493   408369   202731   205638
# ...

# %%
# 5. 합계를 지우고 총인구 내림차순으로 정렬
seoul_df_1.drop(index=[0]).sort_values('총인구', ascending = False)
# Out:
#      자치구      세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  \
# 24   송파구  266550  671994  326511  345483  665282  323228  342054   6712
# 16   강서구  256042  608361  296098  312263  601696  292871  308825   6665
# 23   강남구  231219  557865  267314  290551  552976  264834  288142   4889
# 11   노원구  217999  555803  269762  286041  551902  268144  283758   3901
# 21   관악구  258536  522292  262428  259864  504445  253911  250534  17847
# 12   은평구  203431  490253  237542  252711  485902  235674  250228   4351
# 15   양천구  176559  473087  233189  239898  469221  231409  237812   3866
# 8    성북구  187234  453902  220024  233878  442226  215421  226805  11676
# 22   서초구  174225  445164  213279  231885  440954  211156  229798   4210
# 17   구로구  171751  440396  220903  219493  408369  202731  205638  32027
# 25   강동구  177490  438225  217570  220655  434027  215588  218439   4198
# 7    중랑구  179600  411552  204411  207141  406868  202526  204342   4684
# ...

# %% [markdown]
# # 10. 열 추가 - 파생변수
# 1. 총인구 대비 외국인의 비율을 계산한 값을 **외국인비율** 컬럼을 만들어 넣기 (외국인/총인구 * 100)
# 1. 총인구 대비 고령자의 비율을 계산한 값을 **고령자비율** 컬럼을 만들어 넣기

# %%
# 1. 총인구 대비 외국인의 비율을 계산한 값을 외국인비율 컬럼을 만들어 넣기 (외국인/총인구 * 100)
seoul_df_1['외국인비율'] = (seoul_df_1['외국인']/seoul_df_1['총인구'])*100
seoul_df_1
# Out:
#      자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0     합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 1    종로구    73879    164348    79962    84386   154549    75749    78800
# 2     중구    60903    135139    66582    68557   126082    62376    63706
# 3    용산구   108497    245411   119985   125426   229909   111262   118647
# 4    성동구   134543    314551   154672   159879   306532   150937   155595
# 5    광진구   161407    371671   180206   191465   357149   173946   183203
# 6   동대문구   160489    364962   180381   184581   349308   174476   174832
# 7    중랑구   179600    411552   204411   207141   406868   202526   204342
# 8    성북구   187234    453902   220024   233878   442226   215421   226805
# 9    강북구   143139    327511   159853   167658   323862   158440   165422
# 10   도봉구   137479    345041   168833   176208   342861   168009   174852
# 11   노원구   217999    555803   269762   286041   551902   268144   283758
# ...

# %%
# 2. 총인구 대비 고령자의 비율을 계산한 값을 고령자비율 컬럼을 만들어 넣기
seoul_df_1['고령자비율'] = (seoul_df_1['고령자']/seoul_df_1['총인구'])*100
seoul_df_1
# Out:
#      자치구       세대       총인구       남자       여자      한국인    한국인남자    한국인여자  \
# 0     합계  4237610  10112070  4948481  5163589  9838892  4817507  5021385
# 1    종로구    73879    164348    79962    84386   154549    75749    78800
# 2     중구    60903    135139    66582    68557   126082    62376    63706
# 3    용산구   108497    245411   119985   125426   229909   111262   118647
# 4    성동구   134543    314551   154672   159879   306532   150937   155595
# 5    광진구   161407    371671   180206   191465   357149   173946   183203
# 6   동대문구   160489    364962   180381   184581   349308   174476   174832
# 7    중랑구   179600    411552   204411   207141   406868   202526   204342
# 8    성북구   187234    453902   220024   233878   442226   215421   226805
# 9    강북구   143139    327511   159853   167658   323862   158440   165422
# 10   도봉구   137479    345041   168833   176208   342861   168009   174852
# 11   노원구   217999    555803   269762   286041   551902   268144   283758
# ...

# %% [markdown]
# # 11. 기술 통계정보
# 1. 아래를 조회하는데 합계 행은 빼고 계산한다.
# 1. 총인구 컬럼의 평균, 합계, 중위값, 표준편차, 분산, 데이터개수
# 1. 외국인과 고령자의 평균, 표준편차 조회
# 1. 외국인이 가장 적은 행을 조회

# %%
# 1. 아래를 조회하는데 합계 행은 빼고 계산한다.
seoul_df_2 = seoul_df_1.drop(index = [0])
seoul_df_2
# Out:
#      자치구      세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  \
# 1    종로구   73879  164348   79962   84386  154549   75749   78800   9799
# 2     중구   60903  135139   66582   68557  126082   62376   63706   9057
# 3    용산구  108497  245411  119985  125426  229909  111262  118647  15502
# 4    성동구  134543  314551  154672  159879  306532  150937  155595   8019
# 5    광진구  161407  371671  180206  191465  357149  173946  183203  14522
# 6   동대문구  160489  364962  180381  184581  349308  174476  174832  15654
# 7    중랑구  179600  411552  204411  207141  406868  202526  204342   4684
# 8    성북구  187234  453902  220024  233878  442226  215421  226805  11676
# 9    강북구  143139  327511  159853  167658  323862  158440  165422   3649
# 10   도봉구  137479  345041  168833  176208  342861  168009  174852   2180
# 11   노원구  217999  555803  269762  286041  551902  268144  283758   3901
# 12   은평구  203431  490253  237542  252711  485902  235674  250228   4351
# ...

# %%
# 2. 총인구 컬럼의 평균, 합계, 중위값, 표준편차, 분산, 데이터개수
seoul_df_2.select_dtypes(exclude=['object']).agg(['mean','sum','median','std','var','count']).T
# Out:
#                 mean           sum         median            std  \
# 세대     169504.400000  4.237610e+06  171751.000000   52228.619313
# 총인구    404482.800000  1.011207e+07  406715.000000  128664.735948
# 남자     197939.240000  4.948481e+06  203472.000000   62441.763285
# 여자     206543.560000  5.163589e+06  207141.000000   66410.843680
# 한국인    393555.680000  9.838892e+06  394353.000000  130305.697044
# 한국인남자  192700.280000  4.817507e+06  192215.000000   63112.814258
# 한국인여자  200855.400000  5.021385e+06  202138.000000   67331.638251
# 외국인     10927.120000  2.731780e+05    9057.000000    8369.590678
# 남자외국인    5238.960000  1.309740e+05    4167.000000    4769.194861
# 여자외국인    5688.160000  1.422040e+05    4851.000000    3772.578083
# 세대당인구       2.303600  5.759000e+01       2.270000       0.167528
# 고령자     55296.800000  1.382420e+06   56284.000000   15035.905515
# 외국인비율       3.162069  7.905173e+01       2.572361       2.540405
# ...

# %%
# 3. 외국인과 고령자의 평균, 표준편차 조회
seoul_df_2[['외국인','고령자']].agg(['mean','std'])
# Out:
#                외국인           고령자
# mean  10927.120000  55296.800000
# std    8369.590678  15035.905515

# %%
# 4. 외국인이 가장 적은 행을 조회

# %%
seoul_df_2['외국인'].min()
# Out:
# 2180

# %% [markdown]
# # 12. DataFrame 병합하기
# ### seoul_cctv.csv 파일
# - 서울 자치구 연도별 CCTV 데이터 셋 [서울열린데이터광장](http://data.seoul.go.kr/dataList/OA-2734/C/1/datasetView.do)
#
#
# 1. seoul_cctv.csv 파일을 DataFrame으로 읽기
# 2. 서울시 자치구별 인구 DataFrame과 서울시 자치구 CCTV 데이터 셋을 **자치구명을 기준으로** 결합하여 하나의 DataFrame으로 만드시오.

# %%
# 1. seoul_cctv.csv 파일을 DataFrame으로 읽기
cctv_df = pd.read_csv('seoul_cctv.csv')
cctv_df
# Out:
#      기관명  2014년 CCTV 수  2015년 CCTV 수  2016년 CCTV 수
# 0    강남구           430           584           932
# 1    강동구            99           155           377
# 2    강북구           120           138           204
# 3    강서구           258           184            81
# 4    관악구           260           390           613
# 5    광진구            78            53           174
# 6    구로구           173           246           323
# 7    금천구            51           269           354
# 8    노원구            57           451           516
# 9    도봉구           159            42           386
# 10  동대문구            23           198           579
# 11   동작구           341           103           314
# 12   마포구           118           169           379
# 13  서대문구            50            68           292
# 14   서초구           157           336           398
# 15   성동구            91           241           265
# 16   성북구            78           360           204
# ...

# %%
# 2. 서울시 자치구별 인구 DataFrame과 서울시 자치구 CCTV 데이터 셋을 자치구명을 기준으로 결합하여 하나의 DataFrame으로 만드시오.
# seoul_df_1.info(), cctv_df.info()
new_df = seoul_df_1.merge(cctv_df, left_on = '자치구', right_on = '기관명', how ='inner').drop(columns = '기관명')
new_df
# Out:
#      자치구      세대     총인구      남자      여자     한국인   한국인남자   한국인여자    외국인  \
# 0    종로구   73879  164348   79962   84386  154549   75749   78800   9799
# 1     중구   60903  135139   66582   68557  126082   62376   63706   9057
# 2    용산구  108497  245411  119985  125426  229909  111262  118647  15502
# 3    성동구  134543  314551  154672  159879  306532  150937  155595   8019
# 4    광진구  161407  371671  180206  191465  357149  173946  183203  14522
# 5   동대문구  160489  364962  180381  184581  349308  174476  174832  15654
# 6    중랑구  179600  411552  204411  207141  406868  202526  204342   4684
# 7    성북구  187234  453902  220024  233878  442226  215421  226805  11676
# 8    강북구  143139  327511  159853  167658  323862  158440  165422   3649
# 9    도봉구  137479  345041  168833  176208  342861  168009  174852   2180
# 10   노원구  217999  555803  269762  286041  551902  268144  283758   3901
# 11   은평구  203431  490253  237542  252711  485902  235674  250228   4351
# ...

# %% [markdown]
# # 13. Groupby와 집계
# ## forestfire.csv 파일
# - 포르투칼 북서부 산림 산불관련 데이터 셋 [UCI Machine learning repository](https://archive.ics.uci.edu/ml/datasets/forest+fires)
#
#
# 1. forestfire.csv 파일을 DataFrame으로 읽기
# 1. 어떤 컬럼들이 범주형 컬럼인지 확인.
# 1. 월(month)과 요일(day) 의 고유한(unique) 값들과 각각의 행수 조회
# 1. 요일(day) 별 wind의 평균을 조회
# 1. 요일(day) 별 wind, rain의 평균을 조회
# 1. 요일(day) 별 wind, rain의 평균과 합계과 개수 조회
# 1. 요일(day) 별로 wind는 평균을 rain은 합계와 최대값을 조회
# 1. 월(month) 그리고 요일별(day) temp의 최대값과 최소값을 조회
# 1. X좌표(X), Y좌표(Y)별 temp의 평균울 pivot table로 조회

# %%
# 1. forestfire.csv 파일을 DataFrame으로 읽기
forest_df = pd.read_csv('forestfire.csv')
forest_df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
# 2.  어떤 컬럼들이 범주형 컬럼인지 확인.
# 변수형 컬럼은 어떻게 알수 있는거지? 
forest_df.info() # TODO
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
# 3. 월(month)과 요일(day) 의 고유한(unique) 값들과 각각의 행수 조회
forest_df['month'].nunique() # 12
forest_df['day'].nunique() # 7
# Out:
# 7

# %%
# 4. 요일(day) 별 wind의 평균을 조회
forest_df.groupby('day')['wind'].mean()
# Out:
# day
# fri    4.494118
# mon    3.737838
# sat    3.758333
# sun    4.123158
# thu    3.711475
# tue    4.271875
# wed    3.912963
# Name: wind, dtype: float64

# %%
# 5. 요일(day) 별 wind, rain의 평균을 조회
forest_df.groupby('day')[['wind','rain']].mean()
# Out:
#          wind      rain
# day
# fri  4.494118  0.018824
# mon  3.737838  0.000000
# sat  3.758333  0.000000
# sun  4.123158  0.010526
# thu  3.711475  0.000000
# tue  4.271875  0.131250
# wed  3.912963  0.003704

# %%
# 6. 요일(day) 별 wind, rain의 평균과 합계과 개수 조회
forest_df.groupby('day')[['wind','rain']].agg(['mean','count'])
# Out:
#          wind            rain
#          mean count      mean count
# day
# fri  4.494118    85  0.018824    85
# mon  3.737838    74  0.000000    74
# sat  3.758333    84  0.000000    84
# sun  4.123158    95  0.010526    95
# thu  3.711475    61  0.000000    61
# tue  4.271875    64  0.131250    64
# wed  3.912963    54  0.003704    54

# %%
# 7. 요일(day) 별로 wind는 평균을 rain은 합계와 최대값을 조회
forest_df.groupby('day').agg({'wind' : 'mean',
                             'rain' : ['sum','max']})
# Out:
#          wind rain
#          mean  sum  max
# day
# fri  4.494118  1.6  1.4
# mon  3.737838  0.0  0.0
# sat  3.758333  0.0  0.0
# sun  4.123158  1.0  1.0
# thu  3.711475  0.0  0.0
# tue  4.271875  8.4  6.4
# wed  3.912963  0.2  0.2

# %%
# 8. 월(month) 그리고 요일별(day) temp의 최대값과 최소값을 조회 --> 복수열 기준 그루핑 
forest_df.groupby(['month','day'])['temp'].agg(['max','min'])
# Out:
#             max   min
# month day
# apr   fri  16.7  16.7
#       mon  10.9  10.9
#       sat   9.3   9.3
#       sun  17.6  13.4
#       thu   5.8   5.8
# ...         ...   ...
# sep   sat  30.2  15.4
#       sun  28.3  12.2
#       thu  27.7  12.9
#       tue  24.3  13.1
#       wed  26.4  10.5
#
# [64 rows x 2 columns]

# %%
# 9. X좌표(X), Y좌표(Y)별 temp의 평균울 pivot table로 조회
forest_df.pivot_table(values =['X','Y'] ,index = 'temp',aggfunc='mean' ) 
# TODO
# Out:
#              X         Y
# temp
# 2.2   4.000000  6.000000
# 4.2   6.000000  3.000000
# 4.6   3.833333  3.833333
# 4.8   4.000000  6.000000
# 5.1   6.200000  5.000000
# ...        ...       ...
# 32.3  3.000000  4.000000
# 32.4  2.500000  3.500000
# 32.6  4.000000  5.000000
# 33.1  2.000000  5.000000
# 33.3  6.000000  5.000000
#
# [192 rows x 2 columns]
