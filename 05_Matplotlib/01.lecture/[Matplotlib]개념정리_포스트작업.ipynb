# %% [markdown]
# # Unit01.Matplotlib 개요
# - 데이터의 시각화를 위한 파이썬 패키지이다.
# - 2차원 그래프를 위한 패키지이며 확장 API를 이용하면 3D 그래프 등 다양한 형식의 시각화 지원이 가능하다.
# - Matplotlib는 Seabone, pandas등 과 같은 파이썬 기반의 다른 시각화 패키지의 기반이다.

# %% [markdown]
# ## 1.1 장점
# - 동작하는 OS를 가리지 않는다.
# - Matlab과 유사한 사용자 인터페이지를 가진다.
# - 그래프에 대한 상세한 설정을 할 수 있다.
# - 다양한 출력 형식으로 저장할 수 있다.

# %% [markdown]
# ## 1.2 그래프 구성요소
# 1. figure : 전체 그래프가 위치할 기본 틀
# 1. axes(subplot) : 하나의 그래프를 그리기 위한 공간, figure에 한개 이상의 axies(subplot)로 구성가능하다.
# 1. axis : 축
# 1. ticks : major tick, minor tick
# 1. title : 제목
# 1. legend : 범례, 하나의 axes내에 여러 그래프를 그린 경우 그것에 대한 설명
# ![Parts of a Figure](https://matplotlib.org/stable/_images/anatomy.png)

# %%
# %matplotlib inline
# %matplotlib qt

import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(15,7), facecolor='gray') #facecolor: figure의 배경색
axes1 = fig.add_subplot(1,2,1)
axes2 = fig.add_subplot(1,2,2)

axes1.plot([1,2,3,4,5], [10,20,30,40,50], label='line1')
axes1.plot([1,2,3,4,5], [50,40,30,20,10], label='line2')
axes2.scatter(np.random.randint(100, size=50), np.random.randint(100, 200, size=50), color='r')

fig.suptitle('Example of Plot', size=25, color='blue') #size: 폰트크기, color: 글자색
axes1.set_title("PLOT 1", size=20)
axes2.set_title("Plot 2", size=20)

axes1.set_xlabel("X축", size=15)
axes1.set_ylabel("Y축", size=15)
axes2.set_xlabel("가격1", size=15)
axes2.set_ylabel('가격2', size=15)

axes1.legend()
axes1.grid(True)
plt.show()

# %% [markdown]
# ## 1.2 그래프 그리기
# 1. 모듈을 임포트한다.
#     - import matplotlib.pypplot as plt
#     - 2차원 그래프를 그리기 위한 함수를 제공하는 모듈을 임포트한다.
#     - 별칭(alias)로 plt를 관레적으로 사용한다.
# 1. 그래프를 그린다.
#     - 방법1) pypplot모듈을 이용해 그린다.
#     - 방법2) Figure와 Axes객체를 생성해서 그린다.
# 1. 그래프에 필요한 설정을 한다.
#     - todo
#
# 1. 화면에 그린다.
#     - 지연 래더링 메카니즘 (?) # todo
#     - 마지막에 pyplot.show()호출 시 그래프를 그린다.
#     - 주피터 노트북 맨 마지막 코드에 ;를 붙이는 것으로 대체할 수 있다.

# %% [markdown]
# ## 1.3 그래프를 그리는 2가지 방법
# ### 1.3.1 pyplot모듈을 이용
# - pyplot모듈이 그래프를 그리는 함수와 Axes(subplot)설정 관련한 함수를 제공한다.

# %%
# TODO : 내용이 빠짐.

# %% [markdown]
# ### 1.3.2 figure, Axes 객체 이용
# - Figure에 axes를 추가한 뒤 axes에 그래프를 그린다.
# - axes생성 방법은 2가지가 있다.
# 1. figure.add_subplot()메소드 이용
#     - figure를 먼저 생성한 후 axes들을 추가한다.
# 1. pyplot.subplots() 함수 이용
#     - figure와 axes배열을 동시에 생성한다.

# %% [markdown]
# #### 1.3.2.1 figure.add_subplot
# - figure객체에 axes를 추가하는 형태이다.
# - figure.add_subplot(nrows, ncols, index)
#     - nrows : 총 행수
#     - ncols : 총 열수
#     - index : axes위치
#
# # TODO : 아래 그림에 대한 설명 추가
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.10.30.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.10.30.png)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (10, 10)) # figure객체 생성

#figure에 axes(subplot) 을 추가 : nrows(총행수), ncols(총열수), index(axes위치) 지정
ax1 = fig.add_subplot(2,2,1) 
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(223) # 쉼표없이 지정가능
ax4 = fig.add_subplot(224)

# 그래프 내부에 글씨를 써보자 : ax1.text(0.5,0.5,"안녕") 
axes = [ax1, ax2, ax3, ax4]
for i, ax in enumerate(axes, start = 1):
    txt = f'ax {i}'
    ax.text(0.5, 0.5, txt, fontsize = 25) # text(x위치, y위치, 텍스트) : 텍스트의 left botton이 위치할 곳을 지정

plt.show()

# %% [markdown]
# > 연습1 ) 다음 아래와 같은 그래프를 그려보자.
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%209.59.49.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%209.59.49.png)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (10,10))

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 3)
ax3 = fig.add_subplot(1, 2, 2) 

for i, ax in enumerate([ax1, ax2, ax3], start = 1):
    ax.text(0.5, 0.5, f'ax{i}', fontsize = 20)
    ax.set_title(f'ax label{i}')
    
    # 각 축에 레이블 붙이기
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    
plt.tight_layout() # 각각의 그래프 사이 간격주기 
plt.show()

# %% [markdown]
# > 연습2 ) 다음 아래과 같은 그래프를 그려보자
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.00.17.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.00.17.png)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (20,10))

ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(3, 3, 3)
ax4 = fig.add_subplot(3, 3, 6)
ax5 = fig.add_subplot(3, 3, 9)

for i, ax in enumerate([ax1, ax2, ax3, ax4, ax5], start = 1):
    ax.text(0.5, 0.5, f'ax{i}', fontsize = 30)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1.3.2.2 pypplot.subplots
# - pyplot.subplot(nrows, ncols)
# - nrows, ncols 로 axes갯수와 위치를 지정한다.
# - figure와 axes(subplot)들을 담은 ndarray로 반환한다.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize = (10,10)) # figure와 axes를 튜플로 반환한다. 

ax1, ax2, ax3, ax4 = axes.flatten() # todo : flatten한 이유가 뭐지?

for i, ax in enumerate([ax1, ax2, ax3, ax4], start = 1):
    x, y = 0.5, 0.5
    ax.text(x, y, f'ax {i}', fontsize = 20)
    
plt.show()

# %% [markdown]
# todo : 매번 ?? 지정하면 귀찮으니 넘ㅍ
# subplot자체에서 numpy를 사용하기 때문에 import하지 않아도 numpy 사용이 가능하다.

# %% [markdown]
# ## 1.4 색상과 스타일
# ### 1.4.1 색지정
# color 또는 c 속성을 이용해 지정할 수 있다.
#
#
# 1. 방법1 : 색상이름으로 지정
# 색이름 또는 약자로 지정이 가능하다.
# [color example code](https://matplotlib.org/2.0.2/examples/color/named_colors.html)
# | 문자열 | 약자 |
# |-|-|
# | blue |b |
# | green | g |
# | red | r |
# | cyan | c |
# | magenta | m |
# | yellow | y |
# | black | k |
# | white | w |
#
# 1. 방법2 : HTML 컬러문자열로 지정
# \#으로 시작하며 RGC성분으로 16진수로 표현한다.
# [HTML color](https://htmlcolorcodes.com/)
#
# 1. 방법3 : 0-1 회색조로 지정
# 0(검정) ~ 1(흰색) 사이의 실수값을 통해 회색조로 표현한다.

# %%
plt.figure(figsize = (5, 5), facecolor = 'y') # facecolor : 배경색
plt.plot([1, 2, 3],[10, 20, 30],color = 'red')
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (10, 10))#, facecolor = 'y') # 배경색

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.plot([1, 2, 3],[10, 20, 30],color = 'peru') # 색이름으로 지정 
ax2.plot([1, 2, 3],[10, 20, 30],color = '#B244B9') # HTML color code
ax3.plot([1, 2, 3],[10, 20, 30],color = '#FF0000A0') # RRGGBBAA : AA(투명도, 0에 가까울수록 투명)
ax4.plot([1, 2, 3],[10, 20, 30],color = '0.6') # 0(검정) ~ 1(흰색) : 회색조

plt.show()

# %% [markdown]
# ### 1.4.2 style.use()
# plt.style.use('스타일')함수를 이용해 스타일을 지정할 수 있다.
# matplotlib는 다양한 스타일들을 미리 정의해 놓고 있다.
# 스타일 목록은 해당 링크에서 확인할 수 있다. [style sheets reference](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, num = 100)

plt.style.use('seaborn') #스타일을 지정해준다. 
# plt.style.use('ggplot')

plt.figure(figsize = (5, 5))
plt.plot(x, x)
plt.plot(x, x + 1)
plt.plot(x, x + 2)
plt.plot(x, x + 3)


plt.show()

# %% [markdown]
# 스타일 초기화
# 스타일 지정 및 실행 후 그리는 그래프는 스타일이 적용된다.
# 따라서 스타일을 초기 하기위해서는 아래와 같이 입력한다.

# %%
# 스타일 초기화
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ### 1.4.3 legend box
# 레전드 박스란?
# 지정방식이 2가지가 있다.
# 1. loc
# 1. bbox_to_anchor

# %% [markdown]
# #### 1.4.3.1 loc

# %% [markdown]
# #### 1.4.3.2 bbox_to_anchor

# %% [markdown]
# # Unit02. 각종 그래프 그리기

# %% [markdown]
# ## 2.1 꺽은선그래프 plot()
# - 점과 점을 선으로 연결한 선(꺾은선)그래프를 표현한다.
# - 시간의 흐름에 따른 변화를 표현할 때 많이 사용한다. 시계열
# - plt.plot([x], y)
#     - x, y의 인수는 {리스트, 튜플, 넘파이의 ndarray, 판다스의 시리즈}의 객체들을 넣을 수 있다.
#     - x와 y의 사이즈는 같아야 한다.
#     - x값은 생략할 수 있다.
#     - 인수가 하나인 경우 y축의 값으로 설정되고 x값은 0에서 len(y)-1범위로 지정된다.
# - 하나의 axes(subplot)에 여러개의 선 그리려면? 같은 axes에 plot()를 여러번 실행한다.
# - 선스타일 지정 가능하다. [line-style reference](https://matplotlib.org/3.0.3/gallery/lines_bars_and_markers/line_styles_reference.html)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 10, num = 100) # 1 - 10

plt.figure(figsize = (5,5))
plt.plot(x, x + 3, linestyle = '-', linewidth = 5) # 선 긁기 지정 가능
plt.plot(x, x + 2, linestyle = '--')
plt.plot(x, x + 1, linestyle = ':')
plt.plot(x, x, linestyle = '-.')

plt.show()

# %% [markdown]
# ### 2.1.1 활용
# > <b>활용1</b> [서울시 연도별 황사 경보발령 현황](http://data.seoul.go.kr/dataList/datasetView.do?infId=OA-2227&srvType=S&serviceKind=1&currentPageNo=1)
# - 연도별 관측일수와 황사최대농도의 변화를 그래프로 시각화 해보자
# - 연도별 주인보발령횟수와 경보발령횟수의 변화를 그래프로 시각화 해보자

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/서울시 연도별 황사 경보발령 현황.csv')
df.head()
# Out:
#      년도  주의보 발령횟수  주의보 발령일수  경보 발령횟수  경보 발령일수  관측일수  최대농도(㎍/㎥/시)
# 0  2006         4         5        1        2    11         2941
# 1  2007         3         4        1        1    12         1355
# 2  2008         1         1        1        1    11          933
# 3  2009         2         3        2        3     9         1157
# 4  2010         4         5        2        3    15         1354

# %%
# 최대농도(㎍/㎥/시) 컬럼 조회 시 불편하니 이름을 '최대농도'로 변경하자
df.rename({df.columns[-1] : '최대농도'}, axis = 1, inplace = True)

# %%
# 연도별 관측일수의 변화 흐름을 시각화 해보자. 
plt.figure(figsize = (10,5))

# x : 시간(년도), y : 관측일수
plt.plot(df['년도'], df['관측일수'])

# 제목, 각 축의 레이블을 입력하자
plt.title('연도별 황사 관측일수 변화')
plt.xlabel('년도') 
plt.ylabel('관측일수')


plt.show()

# %%
# 연도별 주인보 발령횟수와 경보 발령횟수의 변화를 그래프로 시각화 해보자 
plt.figure(figsize = (10, 5))

# plt 설정
plt.plot(df['년도'], df['주의보 발령횟수'], label = '주의보')
plt.plot(df['년도'], df['경보 발령횟수'], label = '주의보', alpha = 0.7) 

# 타이블, 레이블 설정
plt.title('연도별 주의보 및 경보 발령횟수의 변화')
plt.xlabel('년도')
plt.ylabel('발령횟수')

# ticks 설정 
plt.xticks(df['년도'], rotation = 45)
plt.yticks(range(0, 5))
# plt.yticks(df['주의보 발령횟수'].unique())

plt.grid()
plt.legend(fontsize = 15, fancybox = True, shadow = True, ncol = 2)
plt.show()

# %% [markdown]
# - 두 개의 선을 구분하기 위해서 label로 구분한다.
# - 선이 겹치는 것을 구분하기 위해 alpha(투명도)값을 0(투명) - 1(불투명) 지정한다.
# - yticks 설정 전에는 0.5 단위도 표기가 되었다. 년도로 구분하기 때문에 range를 써서 1년 단위로 표현했다. 혹은 df['주의보 발령횟수'].unique()로도 설정이 가능하다
# - legend의 ncol

# %% [markdown]
# > <b>활용2</b> [서울시 연도별 황사 경보발령 현황](http://data.seoul.go.kr/dataList/datasetView.do?infId=OA-2227&srvType=S&serviceKind=1&currentPageNo=1)
# - 최대 농도와 관측일수의 연도별 변화를 시각화 해보자.
# - 하나의 축을 공유하고 두개의 축을 가지는 그래프를 그려보자
#     - subplots() 으로 axes ?? 하기 # todo
#     - axes.twinx(), axes.twiny() 설정하기
#         - axes.twinx()
#         : X축을 기준(공유)하여 2개의 Y축을 가지는 그래프
#         - axes.twiny()
#         : Y축을 기준(공유)하여 2개의 X축을 가지는 그래프

# %%
# 연도별 최대농도와 관측일수를 시각화 해보자.
plt.figure(figsize = (15,5))

# plot설정
plt.plot(df['년도'], df['최대농도'], label = '최대농도')
plt.plot(df['년도'], df['관측일수'], label = '관측일수')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# - 최대농도와 관측일수의 단위(scale)가 맞지 않아 관측일수가 0로 표현되었다.
# - 최대농도와 관측일수의 단위를 축으로 나눠서 표현해보자.

# %%
fig, ax1 = plt.subplots(figsize = (15, 5))

# twin 설정
ax2 = ax1.twinx()

# plot 설정 
ax1.plot(df['년도'], df['최대농도'], label = '최대농도', color = 'g')
ax2.plot(df['년도'], df['관측일수'], label = '관측일수', color = 'b')

# legend 설정방법1. loc
# ax1.legend(loc = 'upper left')
# ax2.legend(loc = 'upper right')
# plt.legend()

# legend 설정 방법2. bbox
ax1.legend(bbox_to_anchor = (0.5, 1), loc = 'lower left')
ax2.legend(bbox_to_anchor = (0.5, 1), loc = 'lower right')

# label 설정 
ax1.set_xlabel('년도')
ax1.set_ylabel('관측일수')
ax2.set_ylabel('최대농도')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '년도'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-430b2cdef435> in <module>
#       5
#       6 # plot 설정
# ...

# %% [markdown]
# - ax1,ax2 색을 구분하기 위해서 color를 설정해줘야 한다.
# - 축이 label도 따로 지정해줘야 한다.

# %% [markdown]
# ## 2.2 산점도 scatter()
# - X와 Y축을 가지는 좌표평면상 관측값들을 **점**으로 찍어 표시하는 그래프이다.
# - **변수간의 상관성**이나 관측값들 간의 군집 분류를 확인할 수 있다.
# - scatter(x, y) 메소드를 사용한다.
#     - x, y값들은 모두 매개변수로 전달된다.
#     - x, y의 인수는 스칼라 실수나 리스트형태(리슽, 튜플, 넘파이의 ndarray, 판다스의 Series)의 객체들을 넣는다.
#     - x, y 원소의 수는 같아야 한다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.arange(1, 1000, 50)
y = np.arange(1, 1000, 50)
z = np.arange(1, 1000, 20)

plt.scatter(x, y)
plt.show()

# %% [markdown]
# x와 z의 원소의 갯수가 같지 않기 때문에 사이즈가 달라서 에러가 발생한다.

# %%
plt.scatter(x, z)
plt.show() # ValueError: x and y must be the same size

# %% [markdown]
# ### 2.2.1 설정
# - market : 점의 모양 [markers](https://matplotlib.org/stable/api/markers_api.html)
# - s : 마커의 크기
# - alpha : 투명도 , 0(투명) - 1(불투명) 사이의 실수를 지정한다.

# %%
np.random.seed(0)
plt.figure(figsize=(10,10))

plt.scatter(x=np.random.randint(1,5,30),
            y=np.random.randint(1,5,30),
            marker='2',
            s=100,
            color='r')
plt.scatter(x=np.random.randint(5,10,30),
            y=np.random.randint(5,10,30),
            marker='v',
            s=100)

plt.show()

# %%
plt.plot([1,2,3,4,5],[10,20,30,40,50], marker='o', markersize=10)
# plt.scatter([1,2,3,4,5],[10,20,30,40,50])
plt.show()

# %% [markdown]
# ### 2.2.2 활용
# > <b>활용 1) </b> [서울시 연도별 황사 경보발령 현황](http://data.seoul.go.kr/dataList/datasetView.do?infId=OA-2227&srvType=S&serviceKind=1&currentPageNo=1)
# - 경보 발령횟수와 관측일수 간의관계

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('data/서울시 연도별 황사 경보발령 현황.csv')

plt.figure(figsize=(7,7))
plt.scatter(df['관측일수'], df['경보 발령횟수'])

plt.xlabel('관측일수')
plt.ylabel('경보 발령횟수')

plt.show()

# %% [markdown]
# > <b>활용2 )</b> 상관계수
# - 이건 뭐지.
# TODO 강의 다시 들어야 함

# %% [markdown]
# ## 2.3 막대그래프 Bar()
# - 수량을 막대형식으로 나타낸 그래프
# - axes.bar(x, height) 메소드
#     - 수직막대 그래프
#     - x : 분류 값
#     - height : 막대높이, 갯수
# - axes.harh(y, width) 메소드
#     - 수평막대 그래프
#     - y :
#     - wideh : 막대 너비

# %%
import numpy as np
import matplotlib.pyplot as plt

fruits = ['배', '사과', '수박']
amount = [10,15,5]
fig, axes = plt.subplots(2,1, figsize=(5, 8))

axes[0].bar(fruits, amount, width=0.5) #0 ~ 1 (기본: 0.8)
axes[0].set_title('수직막대그래프')
axes[0].set_xlabel('과일')
axes[0].set_ylabel('수량')
axes[0].grid(True)


axes[1].barh(fruits, amount, height=0.4)
axes[1].set_title('수평막대그래프')
axes[1].set_ylabel('과일')
axes[1].set_xlabel('수량')
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3.1 활용
# > <b>활용1 )</b> [강수량추이](http://www.index.go.kr/potal/main/EachDtlPageDetail.do?idx_cd=1401)
# - 2009년 계절별 강수량 비교해보자.
# - 년도별 봄의 강수량을 비교해보자.
# - ? ㅁ
# - TODO :이부분 수업 들어야 함

# %%
import pandas as pd
df = pd.read_excel('data/강수량.xlsx')
df.set_index('계절',inplace=True)
df
# Out:
#      2009   2010    2011   2012   2013   2014   2015   2016   2017
# 계절
# 봄   231.3  302.9   256.9  256.5  264.3  215.9  223.2  312.8  118.6
# 여름  752.0  692.6  1053.6  770.6  567.5  599.8  387.1  446.2  609.7
# 가을  143.1  307.6   225.5  363.5  231.2  293.1  247.7  381.6  172.5
# 겨울  142.3   98.7    45.6  139.3   59.9   76.9  109.1  108.1   75.6

# %%
# 2009년 계절별 강수량 비교 
plt.figure(figsize = (7, 10))

plt.bar(df.index, df[2009])

# 막대그래프 상단에 수치를 입력해보자 
for idx, rain in enumerate(df[2009]):
    plt.text(idx-0.2, rain + 1, rain, fontsize = 15)

plt.show()

# %% [markdown]
# - 막대 그래프 상단에 수치를 입력하려면?
# x축 :
# y축 :

# %%
# 연도별 봄의 강수량 비교 - 수직막대 그래프 
plt.figure(figsize = (5, 5))

plt.bar(df.columns, df.loc['봄'])

plt.title('연도별 봄의 강수량')
plt.xlabel('연도')
plt.ylabel('강수량')
plt.xticks(df.columns.astype('int'), rotation = 45)

plt.show()

# %%
# 연도별 봄의 강수량 비교 - 수평 그래프 
plt.figure(figsize = (5, 5))

plt.barh(df.columns, df.loc['봄'])

plt.title('연도별 봄의 강수량')
plt.ylabel('연도')
plt.xlabel('강수량')
plt.yticks(df.columns.astype('int'), rotation = 45)

plt.show()

# %% [markdown]
# > <b>활용2 )</b> 다이아몬드
# todo : 놓친부분

# %% [markdown]
# ## 2.4 파이차트 pie()
# - 각 범주()가 데이터에서 차지하는 비율을 나타내는데 사용한다.
# - pie(x, labels, autopct, textprops, explode) 메소드
#     - x :
#     - labels :
#     - autopct :
#     - textprops :
#     - explode

# %%
import matplotlib.pyplot as plt

labels = ['사과', '배', '복숭아', '수박', "딸기"]
amount = [20,10,40,5,60]

plt.figure(figsize=(10,10))
plt.pie(amount, labels=labels, autopct="%.2f%%", 
       shadow=True,
       textprops={'fontsize':15},
       explode=[0,0.2,0,0,0.2]
       )

plt.show()

# %%
# todo : 설명

# %% [markdown]
# ### 2.4.2 활용
# > - <b></b>

# %% [markdown]
# ## 2.5 히스토그램 hist()
# - 표로 된 도수 분포표를 그래프로 나타낸 것
# - hist(data, [bins = 계급갯수]) 메소드
#     - data : 리스트형의 객체를 전달한다.

# %%
### 2.5.1 활용

# %%
## 2.6 상자그래프(Box plot)

# %%
### 2.6.2 활용

# %%
# Unit03. 판다스 시각화

# %%
## 3.1 plot()

# %%
## 3.2 막대그래프

# %%
## 3.3 파이차트

# %%
## 3.4 히스토그램

# %%
## 3.5 KED(밀도그래프)

# %%
## 3.6 상자그래프(box plot)

# %%
## 3.7 산점도(scratter plot)

# %%
## 3.8 판다스 datetime사용

# %%
# Unit04. Seaborn

# %%
## 4.1 ?? 그래프

# %%
### 4.1.1 rugplot

# %%
### 4.1.2 kdeplot

# %%
### 4.1.3 distplot

# %%
## 4.2 범주형

# %%
### 4.2.1 boxplot

# %%
### 4.2.2 violinplot

# %%
### 4.2.3 swarmplot

# %%
### 4.2.4 countplot

# %%
## 4.3 ???

# %%
### 4.3.1 scatterplot

# %%
### 4.3.2 implot

# %%
### 4.3.3 jointplot

# %%
### 4.3.4 pairplot

# %%
### 4.3.5 heatmap

# %%
### 4.3.6 lineplot
